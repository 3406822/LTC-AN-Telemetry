# %% [markdown]
# # LTC-AN Training & Evaluation
# **LTC-AN Project | Philip Opoku Brako | KNUST CS 2026**
#
# This notebook covers the full LTC-AN engineering, training and evaluation pipeline:
# - Fabricated dual-stage residual block (depthwise separable + causal attention)
# - Training on identical split and seed as B0 baseline
# - Formal comparison: Macro-F1, AUC-PR, AUC-ROC, inference latency, RAM usage
# - McNemar Chi-Square significance test (alpha=0.05)
# - TensorFlow Lite Micro export to static C++ byte array

# %%
# Reproducibility — run this first before anything else
import numpy as np
import tensorflow as tf
import random
import os

def enforce_reproducibility(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

enforce_reproducibility(42)

# %%
# LTC-AN Architecture — to be implemented during experimental phase
# F-Operation: FABRICATE
# Block: Depthwise Separable Dilated Conv + Causal Multi-Head Self-Attention Pooling
# Engineered model name: LTC-AN
# Kernel K=3 | Dilation d={1,2,4} | d_model=32 | 2-head attention | dropout=0.2
# Optimizer: Adam lr=0.001 | Loss: Focal Cross-Entropy gamma=2.0
# Early stopping patience=10 on val-AUC-PR
