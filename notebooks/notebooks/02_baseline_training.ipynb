# %% [markdown]
# # Baseline Model Training — Standard TCN (B0)
# **LTC-AN Project | Philip Opoku Brako | KNUST CS 2026**
#
# This notebook trains and locks the unmodified baseline TCN (B0):
# - Standard TCN (Bai et al., 2018) — no engineering applied
# - Trained on identical data split and seed as LTC-AN
# - Metrics saved and frozen — baseline is never modified after this

# %%
# Reproducibility — run this first before anything else
import numpy as np
import tensorflow as tf
import random
import os

def enforce_reproducibility(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

enforce_reproducibility(42)

# %%
# To be completed during experimental phase
# Baselines: B0 (standard TCN), B1 (BiLSTM), B2 (Lightweight 1D CNN)
# SEED = 42 | Split: 70/15/15 stratified | 5-fold cross-validation
