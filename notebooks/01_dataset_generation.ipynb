# %% [markdown]
# # Dataset Generation — HIL Telemetry
# **LTC-AN Project | Philip Opoku Brako | KNUST CS 2026**
#
# This notebook covers the hardware-in-the-loop (HIL) telemetry dataset generation pipeline:
# - Arduino + Raspberry Pi 4 sensor stream capture
# - Anomaly injection (SEU, thermal runaway, bus degradation)
# - Labelling and export to CSV

# %%
# To be completed during experimental phase
# Sampling rate: 50 Hz | Duration: 72 hours | Target: >=250,000 labelled windows
